# %%
import numpy
import os
import pandas

def LoadDataFromDirectory(dataDir):
    df_CoreData = pandas.read_csv()

df_CoreData = pandas.read_csv(r"C:\Src\personal\data-tools\datasets\ICPSR_37182-V1\ICPSR_37182\DS0001\37182-0001-Data.tsv",
                              sep='\t')
df_Form1 = pandas.read_csv(r"C:\Src\personal\data-tools\datasets\ICPSR_37182-V1\ICPSR_37182\DS0002\37182-0002-Data.tsv",
                           sep='\t')

# %%
df_Form1
# Out:
#       CASEID    V1  V3  RESPONDENT_ID  ARCHIVE_WT  V13  V16  V17  V1633  \
# 0          1  2017   1          10001    1.161915    3    0    0      2
# 1          2  2017   1          10002    1.161400    3    0    0      2
# 2          3  2017   1          10003    1.097736    3    0    0      2
# 3          4  2017   1          10004    1.044270    3    0    0      1
# 4          5  2017   1          10005    1.033642    3    0    0      2
# 5          6  2017   1          10006    1.139303    3    0    0      3
# 6          7  2017   1          10007    1.050217    3    0    0      3
# 7          8  2017   1          10008    1.045053    3    0    0      2
# 8          9  2017   1          10009    1.086234    3    0    0      3
# 9         10  2017   1          10010    1.087091    3    0    0      2
# 10        11  2017   1          10011    1.154600    3    0    0      2
# 11        12  2017   1          10012    1.117541    3    0    0      2
# ...
